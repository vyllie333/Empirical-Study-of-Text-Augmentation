# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import sys
sys.path.append('/content/drive/MyDrive/Project_HK1_2022/NLP/Code/ViSA')

# %%
pip install -r /content/drive/MyDrive/Project_HK1_2022/NLP/Code/ViSA-master/install.txt

# %%
from torch.utils.data import RandomSampler, DataLoader
import os
import torch
import sys
import datetime
import time
import itertools
from visa import TRAIN, TEST, LOGGER

# %%
from visa.constants import LOGGER
from visa.trainer import train as TRAIN, test as TEST
from visa.trainer_with_ray_tune import main as TRAIN_WITH_RAY

__all__ = ['TRAIN', 'TEST', 'LOGGER']

# %%
LOGGER.info("Start TRAIN process...")
TRAIN()

# %% [markdown]
# ### Test

# %%
ASPECT_LABELS = ["O", "B-SCREEN", "B-CAMERA", "B-FEATURES", "B-BATTERY", "B-PERFORMANCE", "B-STORAGE", "B-DESIGN", "B-PRICE",
                 "B-GENERAL", "B-SER&ACC", "I-SCREEN", "I-CAMERA", "I-FEATURES", "I-BATTERY", "I-PERFORMANCE",
                 "I-STORAGE", "I-DESIGN", "I-PRICE", "I-GENERAL", "I-SER&ACC"]

#Polarity labels
POLARITY_LABELS = ["O", "B-NEGATIVE", "I-NEGATIVE", "B-NEUTRAL", "I-NEUTRAL", "B-POSITIVE", "I-POSITIVE"]

# VnCoreNLP
if os.path.exists("vncorenlp/VnCoreNLP-1.1.1.jar"):
    RDRSEGMENTER = VnCoreNLP("vncorenlp/VnCoreNLP-1.1.1.jar", annotators="wseg", max_heap_size='-Xmx500m')
else:
    RDRSEGMENTER = None

#POS
ABSA_ASPECT_LABELS = ['O', 'B-T', 'I-T']
ABSA_POLARITY_LABELS = ['O', 'B-POS', 'I-POS', 'B-NEG', 'I-NEG', 'B-NEU', 'I-NEU']

# %%
LOGGER.info("Start TEST process...")
TEST()
